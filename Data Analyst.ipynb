# %% [markdown]
# Load `air_fryers_clean_brand_year.csv`.
#
# 1. Verify that the data contain 10 brands and the years 2019-2023.
# 2. Plot the following over time by brand:
#    - average price
#    - average rating
#    - brand market share

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/workspace/MLFinalProject/air_fryers_clean_brand_year.csv")

# %%
df.head()
# Out:
#      category  year       brand  purchase_count  product_count   avg_price  \
# 0  air_fryers  2019     chefman            1146             10   72.963695
# 1  air_fryers  2019      cosori              11              2  159.990000
# 2  air_fryers  2019   cuisinart            1616             22  229.465274
# 3  air_fryers  2019        dash            3011             19   55.176333
# 4  air_fryers  2019  gowise usa            4405             45   83.575551
#
#    avg_rating  compact_share  dual_basket_share  oven_style_share  \
# 0    4.434119       1.000000                0.0          0.780977
# 1    4.581818       1.000000                0.0          0.090909
# 2    4.481312       0.993812                0.0          0.889851
# 3    4.390767       1.000000                0.0          0.973431
# 4    4.552259       0.999773                0.0          0.129398
#
#    rotisserie_share  window_share  market_purchases  brand_share  \
# ...

# %% [markdown]
# # 1.1

# %%
df["brand"].unique()

# 10
# Out:
# array(['chefman', 'cosori', 'cuisinart', 'dash', 'gowise usa',
#        'instant_pot', 'ninja', 'nuwave', 'oster', 'ultrean'], dtype=object)

# %%
df.columns
# Out:
# Index(['category', 'year', 'brand', 'purchase_count', 'product_count',
#        'avg_price', 'avg_rating', 'compact_share', 'dual_basket_share',
#        'oven_style_share', 'rotisserie_share', 'window_share',
#        'market_purchases', 'brand_share', 'log_brand_share'],
#       dtype='object')

# %%
df["brand"].value_counts()
# Out:
# brand
# chefman        5
# cosori         5
# cuisinart      5
# dash           5
# gowise usa     5
# instant_pot    5
# ninja          5
# nuwave         5
# oster          5
# ultrean        5
# Name: count, dtype: int64

# %% [markdown]
# # 1.2

# %%
plt.figure(figsize=(12,6))
df_sorted = df.sort_values("avg_price", ascending=False)

sns.barplot(
    data=df_sorted,
    x="brand",
    y="avg_price",
    palette="Blues_r"
)

plt.title("Average Air Fryer Price by Brand", fontsize=16, weight='bold')
plt.xlabel("Brand", fontsize=12)
plt.ylabel("Average Price ($)", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1903/245179807.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
plt.figure(figsize=(12,6))
df_sorted = df.sort_values("avg_rating", ascending=False)

sns.barplot(
    data=df_sorted,
    x="brand",
    y="avg_rating",
    palette="Blues_r"
)

plt.title("Average Air Fryer Rating by Brand", fontsize=16, weight='bold')
plt.xlabel("Brand", fontsize=12)
plt.ylabel("Average Rating", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1903/3960682108.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
plt.figure(figsize=(12,6))
df_sorted = df.sort_values("brand_share", ascending=False)

sns.barplot(
    data=df_sorted,
    x="brand",
    y="brand_share",
    palette="Blues_r"
)

plt.title("Average Air Fryer Market Share by Brand", fontsize=16, weight='bold')
plt.xlabel("Brand", fontsize=12)
plt.ylabel("Market Share", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1903/1441350237.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# # 1.3

# %% [markdown]
# Common: Compact, oven-style, rotisserie_share
#
# Rare: window, dual-basket,
#
# Are there brands that seem to specialize in different product types?
#
# **Answer:** Yes. With how much of the share they have for some of the features they seem to specialize in the said product.
#
# This includes Chefman with dual-baskets,window, and rotisserie.

# %%
df.head()
# Out:
#      category  year       brand  purchase_count  product_count   avg_price  \
# 0  air_fryers  2019     chefman            1146             10   72.963695
# 1  air_fryers  2019      cosori              11              2  159.990000
# 2  air_fryers  2019   cuisinart            1616             22  229.465274
# 3  air_fryers  2019        dash            3011             19   55.176333
# 4  air_fryers  2019  gowise usa            4405             45   83.575551
#
#    avg_rating  compact_share  dual_basket_share  oven_style_share  \
# 0    4.434119       1.000000                0.0          0.780977
# 1    4.581818       1.000000                0.0          0.090909
# 2    4.481312       0.993812                0.0          0.889851
# 3    4.390767       1.000000                0.0          0.973431
# 4    4.552259       0.999773                0.0          0.129398
#
#    rotisserie_share  window_share  market_purchases  brand_share  \
# ...

# %% [markdown]
# 'category', 'year', 'brand', 'purchase_count', 'product_count',
#        'avg_price', 'avg_rating', 'compact_share', 'dual_basket_share',
#        'oven_style_share', 'rotisserie_share', 'window_share',
#        'market_purchases', 'brand_share', 'log_brand_share'

# %%
sns.barplot(data=df, x='brand', y='compact_share')
# Out:
# <Axes: xlabel='brand', ylabel='compact_share'>

# %%
sns.barplot(data=df, x='brand', y='dual_basket_share')
# Out:
# <Axes: xlabel='brand', ylabel='dual_basket_share'>

# %%
sns.barplot(data=df, x='brand', y='oven_style_share')
# Out:
# <Axes: xlabel='brand', ylabel='oven_style_share'>

# %%
sns.barplot(data=df, x='brand', y='rotisserie_share')
# Out:
# <Axes: xlabel='brand', ylabel='rotisserie_share'>

# %%
sns.barplot(data=df, x='brand', y='window_share')
# Out:
# <Axes: xlabel='brand', ylabel='window_share'>

# %%
sns.barplot(data=df, x='year', y='purchase_count')
# Out:
# <Axes: xlabel='year', ylabel='purchase_count'>

# %% [markdown]
# # 1.4
#
# The most expensive brands are cuisinart, oster, ninja, and nuwave being close in price range. There is a significant drop between the rest after. In terms of shares, ninja, instapot, and gowise usa have the largest market shares compared to the rest of the brands. Based on the yearly purchase count, the market seems has been decreasing since 2022. 2023 has the lowest airfryer purchase count out of all the years. Derived from these recent trends, the stability of the market decreases over time.
